# %%
import scipy.io
import numpy as np
import healpy
import matplotlib.pyplot as plt

# %%
sav = scipy.io.readsav("/lustre/rbyrne/fhd_outputs/fhd_rlb_process_LWA_Sept2024/Healpix/20240303_093000-093151_41-82MHz_calibrated_core_small_even_cubeYY.sav")
# Out:
# /opt/devel/rbyrne/envs/py310/lib/python3.10/site-packages/scipy/io/_idl.py:339: UserWarning: Using experimental 64-bit array read
#   rectypedesc = _read_typedesc(f)

# %%
sav.keys()
# Out:
# dict_keys(['weights_cube', 'variance_cube', 'res_cube', 'beam_squared_cube', 'obs', 'nside', 'hpx_inds', 'n_avg'])

# %%
len(sav["hpx_inds"])
# Out:
# 5310325

# %%
len(sav["res_cube"][0])
# Out:
# 5310325

# %%
sav["nside"]
# Out:
# 1024.0

# %%
npix = 12*sav["nside"]**2.

# %%
pixel_values = np.full(int(npix), np.nan)
pixel_values[sav["hpx_inds"]] = sav["res_cube"][0]

# %%
# Plot map in Galactic coordinates
proj = healpy.mollview(
    map=pixel_values,
    nest=False,
    title="",
    min=-1000,
    max=1000,
    cbar=True,
    #cmap='Greys_r',
    return_projected_map=False,
    #notext=True,
    unit=None
)
plt.show()
