# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gains = np.load("/lustre/rbyrne/2024-03-03/ddcal/output_gains.npy")

# %%
np.shape(gains)
# Out:
# (4, 1, 352, 192, 2, 2)

# %%
for ant_ind in range(352):
    plt.plot(np.angle(gains[0, 0, ant_ind, :, 0, 0]))
    #plt.plot(np.angle(gains[0, 0, ant_ind, :, 1, 1]))

# %%
for ant_ind in range(352):
    plt.plot(np.abs(gains[0, 0, ant_ind, :, 0, 1]))

# %%
for ant_ind in range(352):
    plt.plot(np.abs(gains[0, 0, ant_ind, :, 1, 0]))

# %%
for ant_ind in range(352):
    plt.plot(np.abs(gains[0, 0, ant_ind, :, 1, 1]))
