# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import pyuvdata
import sys
sys.path.append("/Users/ruby/Astro/rlb_LWA/beam_manipulation")
import jones_to_mueller

# %%
mwa_reference = pyuvdata.UVBeam()
mwa_reference.read_mwa_beam("/Users/ruby/Astro/jones_debugging_Jul2023/mwa_full_embedded_element_pattern.h5")

# %%
np.shape(mwa_reference.freq_array)
# Out:
# (1, 218)

# %%
jones_to_mueller.plot_beam(
    mwa_reference,
    contour_plot=True,
    plot_amplitude=False,
    plot_freq=mwa_reference.freq_array[0,109],
)

# %%
jones_to_mueller.plot_beam(
    mwa_reference,
    contour_plot=True,
    plot_amplitude=False,
    plot_freq=mwa_reference.freq_array[0,109],
    real_part=False,
)

# %%
jones_rot_mwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_mwa.sav")["Jones_rot"]
jones_mwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_mwa.sav")["Jones"]
jones_rot_lwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa.sav")["Jones_rot"]
jones_lwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa.sav")["Jones"]

# %%
# Try these transformations:
#jones_lwa = jones_lwa.T
jones_lwa[0, 0] = -jones_lwa[0, 0]
jones_lwa[1, 1] = -jones_lwa[1, 1]

# %%
np.shape(jones_rot_mwa[0,0])
# Out:
# (2048, 2048)

# %%
use_cmap = cm.get_cmap("seismic").copy()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_rot_mwa[0,0]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_rot_mwa[0,1]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_rot_mwa[1,0]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_rot_mwa[1,1]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_mwa[0,0]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_lwa[0,0]), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_mwa[0,1]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_lwa[0,1]), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_mwa[1,0]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_lwa[1,0]), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_mwa[1,1]), origin="lower", vmin=-150, vmax=150
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(jones_lwa[1,1]), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(
        np.sqrt(np.abs(jones_mwa[0,0])**2.+np.abs(jones_mwa[0,1])**2.)
    ), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(
        np.sqrt(np.abs(jones_mwa[1,0])**2.+np.abs(jones_mwa[1,1])**2.)
    ), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(
        np.sqrt(np.abs(jones_lwa[0,0])**2.+np.abs(jones_lwa[0,1])**2.)
    ), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()

fig, ax = plt.subplots()
cax = ax.imshow(
    np.real(
        np.sqrt(np.abs(jones_lwa[1,0])**2.+np.abs(jones_lwa[1,1])**2.)
    ), origin="lower"
)
cbar = fig.colorbar(cax, extend="both")
plt.show()
