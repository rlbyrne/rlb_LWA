# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import pyuvdata
import sys
sys.path.append("/Users/ruby/Astro/rlb_LWA/beam_manipulation")
import jones_to_mueller

# %%
mwa_reference = pyuvdata.UVBeam()
mwa_reference.read_mwa_beam("/Users/ruby/Astro/jones_debugging_Jul2023/mwa_full_embedded_element_pattern.h5")

# %%
np.shape(mwa_reference.freq_array)
# Out:
# (1, 218)

# %%
jones_to_mueller.plot_beam(
    mwa_reference,
    contour_plot=True,
    plot_amplitude=False,
    plot_freq=mwa_reference.freq_array[0,109],
)

# %%
jones_to_mueller.plot_beam(
    mwa_reference,
    contour_plot=True,
    plot_amplitude=False,
    plot_freq=mwa_reference.freq_array[0,109],
    real_part=False,
)

# %%
jones_rot_mwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_mwa.sav")["Jones_rot"]
jones_mwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_mwa.sav")["Jones"]
jones_rot_lwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa.sav")["Jones_rot"]
jones_lwa = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa.sav")["Jones"]

# %%
# Try these transformations:
#jones_lwa = jones_lwa.T
#jones_lwa[0, 0] = -jones_lwa[0, 0]
#jones_lwa[1, 1] = -jones_lwa[1, 1]

# %%
np.shape(jones_rot_mwa[0,0])
# Out:
# (2048, 2048)

# %%
use_cmap = cm.get_cmap("seismic").copy()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.real(jones_rot_mwa[feed_ind, pol_ind]), interpolation='none', origin="lower", vmin=-150, vmax=150
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.real(jones_rot_lwa[feed_ind, pol_ind]), interpolation='none', origin="lower"
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.real(jones_mwa[feed_ind, pol_ind]), origin="lower", interpolation='none', vmin=-150, vmax=150
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.real(jones_lwa[feed_ind, pol_ind]), origin="lower", interpolation='none'
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.imag(jones_mwa[feed_ind, pol_ind]), origin="lower", interpolation='none'
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.imag(jones_lwa[feed_ind, pol_ind]), origin="lower", interpolation='none'
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
jones_rot_lwa_flipped = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa_flipped.sav")["Jones_rot"]
jones_lwa_flipped = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa_flipped.sav")["Jones"]

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.real(jones_lwa_flipped[feed_ind, pol_ind]), origin="lower", interpolation='none'
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.real(jones_rot_lwa_flipped[feed_ind, pol_ind]), origin="lower", interpolation='none'
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
jones_rot_lwa_no_zenith = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa_no_zenith.sav")["Jones_rot"]
jones_lwa_no_zenith = scipy.io.readsav("/Users/ruby/Astro/jones_debugging_Jul2023/jones_lwa_no_zenith.sav")["Jones"]

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.real(jones_lwa_no_zenith[feed_ind, pol_ind]), origin="lower", interpolation='none'
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
for feed_ind in range(2):
    for pol_ind in range(2):
        cax = ax[feed_ind, pol_ind].imshow(
            np.imag(jones_rot_lwa_no_zenith[feed_ind, pol_ind]), origin="lower", interpolation='none'
        )
        cbar = fig.colorbar(cax, extend="both")
plt.show()
