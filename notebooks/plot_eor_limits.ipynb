# %%
import eor_limits
import importlib
importlib.reload(eor_limits)
import matplotlib.pyplot as plt

# %%
paper_redshifts={
    "beardsley_2016": [7.1]
}

# %%
eor_limits.make_plot()

# %%
paper_redshifts={
    "li_2019": [6.5],
    "patil_2017": [10.1],
    "trott_2020": [6.5],
    "hera_2022": [7.93],
    "rahimi_2021": [6.5],
    "yoshiura_2021": [14.2],
    "dillon_2014": [9.518],
    "beardsley_2016": [7.1],
    "kolopanis_2019": [8.37]
}

# %%
eor_limits.make_plot(
    #plot_as_points=["li_2019", "barry_2019", "patil_2017", "trott_2020", "mertens_2020", "hera_2022", "rahimi_2021", "yoshiura_2021"],
    plot_as_points=["patil_2017", "trott_2020", "mertens_2020", "rahimi_2021", "yoshiura_2021", "eastwood_2019"],
    redshift_range=[6.5, 18.5],
    #redshift_range=[6.5,7.1],
    delta_squared_range = [1e0,3e8],
    shade_limits=False,
    #papers=["kolopanis_2019", "hera_2022b"],
    paper_redshifts=paper_redshifts,
    fontsize=30,
    theory_legend=False,
    bold_papers=["li_2019", "barry_2019","rahimi_2021", "yoshiura_2021","trott_2020", "wilensky_2023"]
)

# %%
eor_limits.make_plot(papers=["beardsley_2016", "dillon_2014"], paper_redshifts=paper_redshifts, shade_limits=False)
