# %%
import pyuvdata
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/fast/rbyrne/20260112_120008-120018_34MHz_casa_05h_calibrated.uvfits"
uv = pyuvdata.UVData()
uv.read(path)

# %%
plt.plot(uv.uvw_array[:, 0], uv.uvw_array[:, 1], ".")
plt.xlabel("u (m)")
plt.ylabel("v (m)")
plt.show()

# %%
plt.plot(uv.uvw_array[:, 0], uv.uvw_array[:, 2], ".")
plt.xlabel("u (m)")
plt.ylabel("w (m)")
plt.show()
