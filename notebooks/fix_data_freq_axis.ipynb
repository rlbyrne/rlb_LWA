# %%
import pyuvdata
import numpy as np
import matplotlib.pyplot as plt

# %%
uvd = pyuvdata.UVData()
uvd.read("/lustre/rbyrne/2024-03-02/10/41-82_10_001_core.uvfits")
# Out:
# The provided name zenith is already used but has different parameters. Adding another entry with the same name but a different ID and parameters.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 400.5799200456924 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.

# %%
uvd.Nspws
# Out:
# 9

# %%
uvd.Nspws = 1
uvd.spw_array = np.array([0])
uvd.flex_spw_id_array = np.zeros_like(uvd.flex_spw_id_array, dtype=int)

# %%
uvd.freq_array
# Out:
# array([40960937.5    , 40984863.28125, 41008789.0625 , ...,
#        86826660.15625, 86850585.9375 , 86874511.71875])

# %%
plt.plot(uvd.freq_array, ".")
plt.ylim([6.5e7, 7.5e7])
# Out:
# (65000000.0, 75000000.0)
