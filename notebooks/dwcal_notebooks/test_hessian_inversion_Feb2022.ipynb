# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import scipy
import scipy.optimize
import pyuvdata
import time
sys.path.append('/Users/ruby/Astro/rlb_LWA/dwcal')
import delay_weighted_cal as dwcal
import dwcal_tests
import importlib
importlib.reload(dwcal)
importlib.reload(dwcal_tests)
import scipy.linalg

# %%
data, model = dwcal.get_test_data(
    model_path="/Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_Aug2021",
    model_use_model=True,
    data_path="/Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_Aug2021",
    data_use_model=False,
    obsid="1061316296",
    pol="XX",
    use_autos=False,
    debug_limit_freqs=5,
    #use_antenna_list=[3, 4, 5, 6, 57, 70, 92, 110],
    #use_antenna_list=[3, 4, 5],
    use_flagged_baselines=False,
)
# Out:
# Loading model from /Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_Aug2021, using the FHD run's model visibilities.
# Telescope location derived from obs lat/lon/alt values does not match the location in the layout file. Using the value from known_telescopes.
# tile_names from obs structure does not match antenna_names from layout
# Fixing auto-correlations to be be real-only, after some imaginary values were detected in data_array.
# There is a gap in the times of baseline (0, 0). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 1). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 2). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 3). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 4). The output may include averages across long time gaps.
# ...

# %%
Nants = data.Nants_data
Nbls = data.Nbls
Ntimes = data.Ntimes
Nfreqs = data.Nfreqs

# Format visibilities
data_visibilities = np.zeros((Ntimes, Nbls, Nfreqs), dtype=complex)
model_visibilities = np.zeros((Ntimes, Nbls, Nfreqs), dtype=complex)
flag_array = np.zeros((Ntimes, Nbls, Nfreqs), dtype=bool)
for time_ind, time_val in enumerate(np.unique(data.time_array)):
    data_copy = data.copy()
    model_copy = model.copy()
    data_copy.select(times=time_val)
    model_copy.select(times=time_val)
    data_copy.reorder_blts()
    model_copy.reorder_blts()
    data_copy.reorder_freqs(channel_order="freq")
    model_copy.reorder_freqs(channel_order="freq")
    if time_ind == 0:
        metadata_reference = data_copy.copy(metadata_only=True)
    model_visibilities[time_ind, :, :] = np.squeeze(
        model_copy.data_array, axis=(1, 3)
    )
    data_visibilities[time_ind, :, :] = np.squeeze(
        data_copy.data_array, axis=(1, 3)
    )
    flag_array[time_ind, :, :] = np.max(
        np.stack(
            [
                np.squeeze(model_copy.flag_array, axis=(1, 3)),
                np.squeeze(data_copy.flag_array, axis=(1, 3)),
            ]
        ),
        axis=0,
    )

# Create gains expand matrices
gains_exp_mat_1 = np.zeros((Nbls, Nants), dtype=int)
gains_exp_mat_2 = np.zeros((Nbls, Nants), dtype=int)
antenna_list = np.unique(
    [metadata_reference.ant_1_array, metadata_reference.ant_2_array]
)
for baseline in range(metadata_reference.Nbls):
    gains_exp_mat_1[
        baseline, np.where(antenna_list == metadata_reference.ant_1_array[baseline])
    ] = 1
    gains_exp_mat_2[
        baseline, np.where(antenna_list == metadata_reference.ant_2_array[baseline])
    ] = 1

# Initialize gains
#gain_init_stddev=0.01
#gains_init = np.random.normal(
#    1.0, gain_init_stddev, size=(Nants, Nfreqs),
#) + 1.0j * np.random.normal(0.0, gain_init_stddev, size=(Nants, Nfreqs),)
gains_init = np.ones((Nants, Nfreqs), dtype=complex)
gains_init[0, :] = 2.
# Expand the initialized values
x0 = np.stack((np.real(gains_init), np.imag(gains_init)), axis=0).flatten()

cov_mat = dwcal.get_weight_mat_identity(Nfreqs, Nbls)

#cov_mat = dwcal.get_weighted_weight_mat(
#    Nfreqs, Nbls, metadata_reference.uvw_array, metadata_reference.freq_array
#)

# %%
np.shape(cov_mat)
# Out:
# (5874, 5, 5)

# %%
print(Nants)
print(Nbls)
# Out:
# 127
# 5874

# %%
if False:
    test_freq = 0
    readout_freq = 1
    delta_gains = 0.0001
    test_grad = dwcal_tests.test_grad
    test_hess = dwcal_tests.test_hess
    for test_ant in range(Nants):

        test_grad(
            test_ant,
            test_freq,
            delta_gains,
            gains_init,
            Nants,
            Nfreqs,
            Nbls,
            model_visibilities,
            gains_exp_mat_1,
            gains_exp_mat_2,
            cov_mat,
            data_visibilities,
            real_part=True,
        )

        test_grad(
            test_ant,
            test_freq,
            delta_gains,
            gains_init,
            Nants,
            Nfreqs,
            Nbls,
            model_visibilities,
            gains_exp_mat_1,
            gains_exp_mat_2,
            cov_mat,
            data_visibilities,
            real_part=False,
        )

        for readout_ant in range(Nants):

            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                readout_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=True,
                real_part2=True,
            )

            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                readout_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=True,
                real_part2=False,
            )

            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                readout_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=False,
                real_part2=True,
            )

            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                readout_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=False,
                real_part2=False,
            )

            # Test hess frequency diagonals
            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                test_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=True,
                real_part2=True,
            )

            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                test_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=True,
                real_part2=False,
            )

            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                test_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=False,
                real_part2=True,
            )

            test_hess(
                test_ant,
                test_freq,
                readout_ant,
                test_freq,
                delta_gains,
                gains_init,
                Nants,
                Nfreqs,
                Nbls,
                model_visibilities,
                gains_exp_mat_1,
                gains_exp_mat_2,
                cov_mat,
                data_visibilities,
                real_part1=False,
                real_part2=False,
            )

# %%
Nants*Nfreqs + Nants * Nfreqs
# Out:
# 1270

# %%
hess_mat = dwcal.hess_dw_cal(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)
jac = dwcal.jac_dw_cal(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)

# %%
hess_mat_inv = np.linalg.inv(hess_mat)

# %%
plt.imshow(
    hess_mat, interpolation='none',
    origin='lower'
)
cbar = plt.colorbar()

# %%
plt.imshow(
    cov_mat[100,:,:], interpolation='none',
    origin='lower'
)
cbar = plt.colorbar()

# %%
def newtons_method_optimizer(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
    step_size = .5,
    covergence_condition = 0.001,
):

    n_iters = 0
    convergence_iters = 0
    while convergence_iters < 3:
        hess_mat = dwcal.hess_dw_cal(
            x0,
            Nants,
            Nfreqs,
            Nbls,
            model_visibilities,
            gains_exp_mat_1,
            gains_exp_mat_2,
            cov_mat,
            data_visibilities,
        )
        hess_mat_inv = np.linalg.inv(hess_mat)
        del hess_mat
        jac = dwcal.jac_dw_cal(
            x0,
            Nants,
            Nfreqs,
            Nbls,
            model_visibilities,
            gains_exp_mat_1,
            gains_exp_mat_2,
            cov_mat,
            data_visibilities,
        )
        x1 = x0 - step_size*np.matmul(hess_mat_inv, jac)
        del hess_mat_inv
        del jac
        cost = dwcal.cost_function_dw_cal(
            x0,
            Nants,
            Nfreqs,
            Nbls,
            model_visibilities,
            gains_exp_mat_1,
            gains_exp_mat_2,
            cov_mat,
            data_visibilities,
        )
        print(f"Iteration {n_iters}, cost func value: {cost}")
        check_conv = np.max(np.abs(x1-x0))
        if check_conv < covergence_condition:
            convergence_iters += 1
        else:
            convergence_iters = 0
        x0 = x1
        n_iters += 1

# %%
def grad_descent_optimizer(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
    covergence_condition = 1e-8,
):

    n_iters = 0
    convergence_iters = 0
    while convergence_iters < 10:
        jac = dwcal.jac_dw_cal(
            x0,
            Nants,
            Nfreqs,
            Nbls,
            model_visibilities,
            gains_exp_mat_1,
            gains_exp_mat_2,
            cov_mat,
            data_visibilities,
        )
        if n_iters == 0:
            step_size = 1./(2*np.max(jac))  # Don't change gains by more than 1/2
        else:
            step_size = np.abs(np.matmul((x0-x_prev).T, jac-jac_prev))/np.sum((jac-jac_prev)**2.)
        print(step_size)
        x1 = x0 - step_size*jac
        cost = dwcal.cost_function_dw_cal(
            x0,
            Nants,
            Nfreqs,
            Nbls,
            model_visibilities,
            gains_exp_mat_1,
            gains_exp_mat_2,
            cov_mat,
            data_visibilities,
            verbose=False
        )
        print(f"Iteration {n_iters}, cost func value: {cost}")
        check_conv = np.max(np.abs(x1-x0))
        if check_conv < covergence_condition:
            convergence_iters += 1
        else:
            convergence_iters = 0
            
        jac_prev = jac
        x_prev = x0
        x0 = x1
        n_iters += 1
        
    return x1

# %%
newtons_method_optimizer(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
    step_size = 1.,
    covergence_condition = 1e-5,
)
# Out:
# Cost func. value: 87449253.8917937
# Iteration 0, cost func value: 87449253.8917937
# Cost func. value: 22128125.868439056
# Iteration 1, cost func value: 22128125.868439056
# Cost func. value: 6349776.957921341
# Iteration 2, cost func value: 6349776.957921341
# Cost func. value: 2580477.4223404047
# Iteration 3, cost func value: 2580477.4223404047
# Cost func. value: 3141061.6152890613
# Iteration 4, cost func value: 3141061.6152890613
# Cost func. value: 2161064.673059288
# Iteration 5, cost func value: 2161064.673059288
# Cost func. value: 2207797.5712582497
# Iteration 6, cost func value: 2207797.5712582497
# Cost func. value: 2021349.9289607657
# Iteration 7, cost func value: 2021349.9289607657
# Cost func. value: 1961242.6156187872
# Iteration 8, cost func value: 1961242.6156187872
# Cost func. value: 3307010.679334472
# Iteration 9, cost func value: 3307010.679334472
# Cost func. value: 2221148.741730082
# Iteration 10, cost func value: 2221148.741730082
# ...

# %%
gains = grad_descent_optimizer(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)
gains = np.reshape(gains, (2, Nants, Nfreqs))
gains = (gains[0,]+ 1.0j* gains[1,])
# Out:
# 3.181709911028826e-07
# Iteration 0, cost func value: 87449253.8917937
# 5.702734931203834e-07
# Iteration 1, cost func value: 39493365.50047616
# 1.0411786368906275e-06
# Iteration 2, cost func value: 20472008.851254202
# 1.8165969694822504e-06
# Iteration 3, cost func value: 12691826.102402754
# 3.02863850912315e-06
# Iteration 4, cost func value: 9440091.513035547
# 4.253967591687025e-06
# Iteration 5, cost func value: 7213334.666325623
# 7.955002891219984e-06
# Iteration 6, cost func value: 4846878.428734882
# 5.065065908594486e-06
# Iteration 7, cost func value: 2895524.7460319176
# 2.712561762014414e-06
# Iteration 8, cost func value: 2629193.9175421
# 2.7181569269588505e-06
# Iteration 9, cost func value: 2319963.5183029063
# 3.898068328447955e-06
# Iteration 10, cost func value: 2251371.1346801734
# 9.983134217063467e-06
# Iteration 11, cost func value: 2180308.4431609106
# 1.0727255097751458e-05
# Iteration 12, cost func value: 2058907.644908951
# 2.3642756388550005e-06
# ...

# %%
plt.scatter(np.real(gains.flatten()), np.imag(gains.flatten()), s=.1)
#plt.xlim([1-.02, 1+.02])
#plt.ylim([-.02, .02])
plt.show()

# %%
def lagrange_cost(
    x,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    weight_mat,
    data_visibilities,
    verbose=True,
    lambda_val=1.0,
):

    gains = np.reshape(x, (2, Nants, Nfreqs))
    gains = gains[0, :, :] + 1.0j * gains[1, :, :]
    cost = lambda_val * np.sum(np.sum(np.angle(gains), axis=0) ** 2.0)
    return cost

def lagrange_jac(
    x,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    weight_mat,
    data_visibilities,
    verbose=True,
    lambda_val=1.0,
):

    gains = np.reshape(x, (2, Nants, Nfreqs))
    gains = gains[0, :, :] + 1.0j * gains[1, :, :]
    grad = (
        2
        * lambda_val
        * np.conj(gains)
        / np.abs(gains) ** 2.0
        * np.sum(np.angle(gains), axis=0)[np.newaxis, :]
    )

    grad = np.stack((np.imag(grad), np.real(grad)), axis=0).flatten()
    return grad

def lagrange_hess(
    x,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    weight_mat,
    data_visibilities,
    verbose=True,
    lambda_val=1.0,
):

    gains = np.reshape(x, (2, Nants, Nfreqs))
    gains = gains[0, :, :] + 1.0j * gains[1, :, :]
    hess = np.zeros((Nants, Nants, Nfreqs, Nfreqs, 3), dtype=float)

    im_part = np.imag(gains)/np.abs(gains)**2.
    real_part = np.real(gains)/np.abs(gains)**2.
    arg_sum = np.sum(np.angle(gains), axis=0)
    
    # Real-real derivative
    term1_rr = 2 * lambda_val * np.einsum("ik,jk->ijk", im_part, im_part)
    term2_rr = 4 * lambda_val * arg_sum * im_part * real_part
    hess[:, :, np.arange(Nfreqs), np.arange(Nfreqs), 0] = term1_rr
    for ant_ind in range(Nants):
        hess[ant_ind, ant_ind, np.arange(Nfreqs), np.arange(Nfreqs), 0] += term2_rr[ant_ind, :]
        
    # Real-imaginary derivative
    term1_ri = -2 * lambda_val *np.einsum("ik,jk->ijk", im_part, real_part)
    term2_ri = 2 * lambda_val * arg_sum * (im_part**2. - real_part**2.)
    hess[:, :, np.arange(Nfreqs), np.arange(Nfreqs), 1] = term1_ri
    for ant_ind in range(Nants):
        hess[ant_ind, ant_ind, np.arange(Nfreqs), np.arange(Nfreqs), 1] += term2_ri[ant_ind, :]
        
    # Imaginary-imaginary derivative
    term1_ii = 2 * lambda_val * np.einsum("ik,jk->ijk", real_part, real_part)
    term2_ii = -1 * term2_rr
    hess[:, :, np.arange(Nfreqs), np.arange(Nfreqs), 2] = term1_ii
    for ant_ind in range(Nants):
        hess[ant_ind, ant_ind, np.arange(Nfreqs), np.arange(Nfreqs), 2] += term2_ii[ant_ind, :]
        
    hess_reformatted = np.zeros((2, Nants * Nfreqs, 2, Nants * Nfreqs), dtype=float)
    hess_reformatted[0, :, 0, :] = np.transpose(
        hess[:, :, :, :, 0], (0, 2, 1, 3)
    ).reshape(Nants * Nfreqs, Nants * Nfreqs)
    hess_reformatted[0, :, 1, :] = np.transpose(
        hess[:, :, :, :, 1], (0, 2, 1, 3)
    ).reshape(Nants * Nfreqs, Nants * Nfreqs)
    hess_reformatted[1, :, 0, :] = np.transpose(
        hess[:, :, :, :, 1], (1, 3, 0, 2)
    ).reshape(Nants * Nfreqs, Nants * Nfreqs)
    hess_reformatted[1, :, 1, :] = np.transpose(
        hess[:, :, :, :, 2], (0, 2, 1, 3)
    ).reshape(Nants * Nfreqs, Nants * Nfreqs)
    del hess
    hess_reformatted = hess_reformatted.reshape(2 * Nants * Nfreqs, 2 * Nants * Nfreqs)
    
    return hess_reformatted

# %%
delta_x = .0001
test_ind = -5
x2 = np.copy(x0)
x2[test_ind] += delta_x/2.
x1 = np.copy(x0)
x1[test_ind] -= delta_x/2.

cost1 = lagrange_cost(
    x1,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)
cost2 = lagrange_cost(
    x2,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)
print((cost2-cost1)/delta_x)
jac = lagrange_jac(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)
print(jac[test_ind])

# %%
delta_x = .0001
test_ind = -5
readout_ind = -5
x2 = np.copy(x0)
x2[test_ind] += delta_x/2.
x1 = np.copy(x0)
x1[test_ind] -= delta_x/2.

jac1 = lagrange_jac(
    x1,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)
jac2 = lagrange_jac(
    x2,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)

hess = lagrange_hess(
    x0,
    Nants,
    Nfreqs,
    Nbls,
    model_visibilities,
    gains_exp_mat_1,
    gains_exp_mat_2,
    cov_mat,
    data_visibilities,
)
print((jac2[readout_ind]-jac1[readout_ind])/delta_x)
print(hess[test_ind, readout_ind])
