# %%
import numpy as np
import pyuvdata
import sys
sys.path.append("/Users/ruby/Astro/rlb_LWA/dwcal")
import importlib
import delay_weighted_cal
importlib.reload(delay_weighted_cal)
import matplotlib.pyplot as plt

# %%
data, model = delay_weighted_cal.get_test_data(
    model_path="/Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_bright_sources_Dec2021",
    model_use_model=True,
    data_path="/Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_bright_sources_Dec2021",
    data_use_model=True,
    obsid="1061316296",
    pol="XX",
    use_autos=False,
    use_flagged_baselines=False,
    use_antenna_list=[3, 4, 5, 6, 57, 70, 92, 110],
)
# Out:
# Loading model from /Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_bright_sources_Dec2021, using the FHD run's model visibilities.
# Telescope location derived from obs lat/lon/alt values does not match the location in the layout file. Using the value from known_telescopes.
# Fixing auto-correlations to be be real-only, after some imaginary values were detected in data_array.
# There is a gap in the times of baseline (0, 0). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 1). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 2). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 3). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 4). The output may include averages across long time gaps.
# ...

# %%
def plot_gains(cal):
    for ant_ind in range(cal.Nants_data):
        plt.plot(np.squeeze(cal.freq_array)/1e6, np.abs(cal.gain_array[ant_ind,0,:,0,0]))
        plt.xlim([np.min(cal.freq_array)/1e6, np.max(cal.freq_array)/1e6])
        plt.ylim([1-.08,1+.08])
        plt.xlabel('Frequency (MHz)')
        plt.ylabel('Gain Amplitude')
    plt.plot([np.min(cal.freq_array)/1e6, np.max(cal.freq_array)/1e6], [1,1], color='white', linestyle='--', linewidth=0.9)
    plt.show()
    
def plot_gains_delay(cal):
    delay_array = np.fft.fftfreq(cal.Nfreqs, d=cal.channel_width)
    delay_array = np.fft.fftshift(delay_array)
    for ant_ind in range(cal.Nants_data):
        gains_fft = np.fft.fftshift(np.fft.fft(cal.gain_array[ant_ind,0,:,0,0]-1))
        plt.plot(delay_array, np.abs(gains_fft))
    plt.ylim([0,5])
    plt.xlabel('Delay (s)')
    plt.ylabel('Gain Error Amp.')
    plt.show()

# %%
cal = delay_weighted_cal.calibration_optimization(
    data,
    model,
    use_wedge_exclusion=False,
    apply_flags=False,
)
# Out:
# use_wedge_exclusion=False: Covariance matrix is the identity
# Time generating covariance matrix: 0.00012623071670532228 minutes
# ...
# Cost func. value: 1472.7194632535404
# Cost func. value: 277.7616436355109
# Cost func. value: 26.37913458337949
# Cost func. value: 5.386430311510886
# Cost func. value: 2.7883742350053833
# Cost func. value: 0.10603255918290497
# Cost func. value: 0.020779443594343194
# Cost func. value: 0.011522988474837178
# Cost func. value: 0.0005166114282360724
# Cost func. value: 0.0003648721647151172
# Cost func. value: 0.0001233587066529402
# Cost func. value: 8.514194613896075e-07
# Cost func. value: 9.7451156126449e-08
# Cost func. value: 2.6732905745621886e-08
# Cost func. value: 1.7674944562166416e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
#          Hessian evaluations: 14
# Optimization terminated successfully.
# ...

# %%
plot_gains(cal)
plot_gains_delay(cal)

# %%
cal_dw = delay_weighted_cal.calibration_optimization(
    data,
    model,
    use_wedge_exclusion=True,
    apply_flags=False,
)
# Out:
# use_wedge_exclusion=True: Generating wedge excluding covariance matrix
# Time generating covariance matrix: 0.0011630972226460774 minutes
# ...
# Cost func. value: 258827.07366657985
# Cost func. value: 77626.36113232267
# Cost func. value: 21284.226147637197
# Cost func. value: 8785.006120749622
# Cost func. value: 4263.845576479208
# Cost func. value: 758.6724957358815
# Cost func. value: 206.46852053456368
# Cost func. value: 31.098628170124083
# Cost func. value: 13.921509121037305
# Cost func. value: 1.4598805942006656
# Cost func. value: 0.5729764269488087
# Cost func. value: 0.08880152016335448
# Cost func. value: 0.033378478688960794
# Cost func. value: 0.003371410789313211
# Cost func. value: 0.0014543805306310958
# Cost func. value: 0.0003107833284140911
# Cost func. value: 8.899075194680219e-05
# Cost func. value: 3.1417510952667263e-06
# Cost func. value: 1.3356307116318483e-06
# Cost func. value: 5.022642218959095e-07
# Cost func. value: 8.94829627802053e-08
# ...

# %%
plot_gains(cal_dw)
plot_gains_delay(cal_dw)

# %%
cal_dw = delay_weighted_cal.calibration_optimization(
    data,
    model,
    use_wedge_exclusion=True,
    apply_flags=False,
    use_newtons_method=True,
)
# Out:
# use_wedge_exclusion=True: Generating wedge excluding covariance matrix
# Time generating covariance matrix: 0.0015171686808268228 minutes
# ...
# Cost func. value: 243860.62765837845
# Iteration 0, cost func value: 243860.62765837845
# Cost func. value: 642228834.561057
# Iteration 1, cost func value: 642228834.561057
# Cost func. value: 674402938906914.4
# Iteration 2, cost func value: 674402938906914.4
# Cost func. value: 133199680846545.44
# Iteration 3, cost func value: 133199680846545.44
# Cost func. value: 26386451700040.695
# Iteration 4, cost func value: 26386451700040.695
# Cost func. value: 5535313659899.269
# Iteration 5, cost func value: 5535313659899.269
# Cost func. value: 14938135935775.664
# Iteration 6, cost func value: 14938135935775.664
# Cost func. value: 85790340649083.64
# Iteration 7, cost func value: 85790340649083.64
# ---------------------------------------------------------------------------
# ...
