# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import scipy
import scipy.optimize
import pyuvdata
import time
sys.path.append('/Users/ruby/Astro/rlb_LWA/dwcal')
import delay_weighted_cal as dwcal
import dwcal_tests
import importlib
importlib.reload(dwcal)
importlib.reload(dwcal_tests)
import scipy.linalg

# %%
data, model = dwcal.get_test_data(
    model_path="/Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_Aug2021",
    model_use_model=True,
    data_path="/Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_Aug2021",
    data_use_model=True,
    obsid="1061316296",
    pol="XX",
    use_autos=False,
    debug_limit_freqs=50,
    #use_antenna_list=[3, 4, 5, 6, 57, 70, 92, 110],
    use_flagged_baselines=False,
)
# Out:
# Loading model from /Users/ruby/Astro/FHD_outputs/fhd_rlb_model_GLEAM_Aug2021, using the FHD run's model visibilities.
# Telescope location derived from obs lat/lon/alt values does not match the location in the layout file. Using the value from known_telescopes.
# tile_names from obs structure does not match antenna_names from layout
# Fixing auto-correlations to be be real-only, after some imaginary values were detected in data_array.
# There is a gap in the times of baseline (0, 0). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 1). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 2). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 3). The output may include averages across long time gaps.
# There is a gap in the times of baseline (0, 4). The output may include averages across long time gaps.
# ...

# %%
antenna_list = np.unique(
    [data.ant_1_array, data.ant_2_array]
)
gains = np.ones((data.Nants_data, data.Nfreqs), dtype=complex)
gains[np.where(antenna_list==5), :] = 2. 
cal_init = dwcal.initialize_cal(data, antenna_list, gains=gains)
data_use = pyuvdata.utils.uvcalibrate(data, cal_init, inplace=False)
# Out:
# UVData object does not have `x_orientation` specified but UVCal does. Matching based on `x` and `y` only

# %%
vis_diff = data_use.diff_vis(data)

# %%
np.max(np.abs(vis_diff.data_array))
# Out:
# 47.964677448932164

# %%
plt.hist(np.abs(np.abs(data_use.data_array).flatten()), bins=50)
plt.show()

# %%
plt.hist(np.abs(np.abs(data.data_array).flatten()), bins=50)
plt.show()

# %%
cal = dwcal.calibration_optimization(
    data_use,
    model,
    use_wedge_exclusion=False,
    log_file_path=None,
    apply_flags=False,
    gain_init_stddev=0.01,
    xtol=1e-5
)
# Out:
# use_wedge_exclusion=False: Covariance matrix is the identity
# Time generating covariance matrix: 0.00045180320739746094 minutes
# ...
# Cost func. value: 2020110.345107428
# Cost func. value: 379035115.56916517
# Cost func. value: 45766.31514828451
# Cost func. value: 3715641.6822691676
# Cost func. value: 16856.60145743046
# Cost func. value: 46560.43386447516
# Cost func. value: 7112.35784734353
# Cost func. value: 13440.99465765332
# Cost func. value: 3373.5159591875345
# Cost func. value: 4622.0485715529
# Cost func. value: 1751.943620651945
# Cost func. value: 2109.031694900961
# Cost func. value: 1012.6586570980699
# Cost func. value: 1067.4278954717338
# Cost func. value: 652.4696019865352
# Cost func. value: 634.8225705924949
# Cost func. value: 465.96981031113137
# Cost func. value: 422.23728123595686
# Cost func. value: 345.3521948741684
# Cost func. value: 250.9110499140725
# Cost func. value: 203.42262522516785
# Cost func. value: 134.92446016330967
# ...

# %%
plt.scatter(np.real(cal.gain_array).flatten(), np.imag(cal.gain_array).flatten(), s=1)
plot_extent = 0.01
plt.xlim([1-plot_extent, 1+plot_extent])
plt.ylim([-plot_extent, plot_extent])
plt.show()

# %%
plt.hist(np.abs(cal.gain_array).flatten(), bins=50)
plt.show()

# %%
np.max(cal.gain_array)
# Out:
# (1.0146692938872914-0.0007113459128378161j)

# %%
cal_wedge_weighted = dwcal.calibration_optimization(
    data_use,
    model,
    use_wedge_exclusion=True,
    log_file_path=None,
    apply_flags=False,
    gain_init_stddev=0.01,
    xtol=1e-5
)
# Out:
# use_wedge_exclusion=True: Generating wedge excluding covariance matrix
# Time generating covariance matrix: 0.0027264515558878583 minutes
# ...
# Cost func. value: 175142405.12733835
# Cost func. value: 32978238951.99918
# Cost func. value: 4052817.211925252
# Cost func. value: 359143430.3230145
# Cost func. value: 957543.4843003773
# Cost func. value: 15197689.072462715
# Cost func. value: 471021.86429770663
# Cost func. value: 875816.3039649389
# Cost func. value: 297016.3716857162
# Cost func. value: 219544.72063876034
# Cost func. value: 123017.736604175
# Cost func. value: 280139.2782605253
# Cost func. value: 96039.67914708954
# Cost func. value: 89575.78559166582
# Cost func. value: 78527.98022132477
# Cost func. value: 66703.99948790521
# Cost func. value: 55350.70060181072
# Cost func. value: 48335.01134942025
# Cost func. value: 46254.81514902803
# Cost func. value: 42872.70060584359
# Cost func. value: 40132.07299807295
# Cost func. value: 37760.28975249456
# ...

# %%
plt.scatter(np.real(cal_wedge_weighted.gain_array).flatten(), np.imag(cal_wedge_weighted.gain_array).flatten(), s=1)
plot_extent = 0.01
plt.xlim([1-plot_extent, 1+plot_extent])
plt.ylim([-plot_extent, plot_extent])
plt.show()

# %%
plt.hist(np.abs(cal_wedge_weighted.gain_array).flatten(), bins=50)
plt.show()

# %%
np.shape(np.where(cal_wedge_weighted.gain_array < .7))
# Out:
# (5, 50)
