# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
frequencies = [
    18,
    23,
    27,
    36,
    41,
    46,
    50,
    55,
    59,
    64,
    73,
    78,
    82,
]

# %%
#virA_peak_value_transit_obs = [
#    1807.43,
#    1851.61,
#    1471.28,
#    964.26,
#    793.867,
#    698.225,
#    644.224,
#    543.298,
#    509.026,
#    416.525,
#    331.193,
#    292.24,
#    197.889,
#]  # Imaged using full array
virA_peak_value_transit_obs = [
    2743.85,
    2967.31,
    2649.12,
    1793.02,
    1533.7,
    1334.73,
    1178.48,
    1054.4,
    942.255,
    846.279,
    653.156,
    579.914,
    404.981,
]  # Core only imaging
virA_peak_value_transit_obs = np.array(virA_peak_value_transit_obs)*2

# Cyg A and Cas A peak values, evaluated with respect to the calibration observation
cygA_peak_value = [
    5362.33,
    5662.28,
    5587.57,
    4841.62,
    4493.14,
    4138.45,
    3858.14,
    3571.84,
    3286.98,
    3037.74,
    2490.04,
    2256.49,
    1682.83,
]
casA_peak_value = [
    2261.99,
    2168.54,
    2011.49,
    1745.69,
    1658.58,
    1519.6,
    1435,
    1322.44,
    1216.57,
    1165.77,
    1013.17,
    958.398,
    756.466,
]  # Very close to the horizon!
cygA_peak_value = np.array(cygA_peak_value)*2
casA_peak_value = np.array(casA_peak_value)*2

# %%
cygA_model_peak_value = [
    8563.78,
    7552.44,
    6938.04,
    5881.8,
    5525.97,
    5173.96,
    4903.47,
    4648.31,
    4430.71,
    4205.99,
    3729.88,
    3564.86,
    3418.15,
]
casA_model_peak_value = [
    5494.01,
    4520.12,
    3860.13,
    2991.75,
    2724.17,
    2454.86,
    2291.78,
    2143.2,
    2036.29,
    1956.29,
    1830.02,
    1841.15,
    1925.68,
]
cygA_model_peak_value = np.array(cygA_model_peak_value)*2
casA_model_peak_value = np.array(casA_model_peak_value)*2

# %%
tauA_cal_flux = [
    3492.860287,
    3129.290626,
    2855.431542,
    2490.712568,
    2365.12748,
    2259.80257,
    2165.716308,
    2077.183589,
    1991.855738,
    1910.720505,
    1781.661034,
    1752.394433,
    1764.635728,
]
virA_cal_flux = [
    3451.279533,
    3464.56795,
    3369.464194,
    3010.675611,
    2807.40382,
    2616.565933,
    2450.483784,
    2314.325336,
    2206.104675,
    2116.682017,
    1921.902199,
    1762.4961,
    1513.790127,
]
casA_cal_flux = [
    64475.25454,
    53945.26893,
    45777.91111,
    34640.98368,
    30882.81112,
    27910.06043,
    25484.87478,
    23431.97515,
    21638.6604,
    20054.80723,
    17627.88166,
    16997.45192,
    17001.76906,
]
cygA_cal_flux = [
    36566.68840287779,
    32892.4026556061,
    29905.249729369887,
    25471.797719274393,
    23807.055411144247,
    22392.559475508173,
    21160.91738632444,
    20061.468251989674,
    19060.28281533748,
    18140.163453639525,
    16557.990636380102,
    15945.200107549737,
    15512.001507135707,
]

# %%
beam_freqs_hz = [
    10000000.0,
    11000000.0,
    12000000.0,
    13000000.0,
    14000000.0,
    15000000.0,
    16000000.0,
    17000000.0,
    18000000.0,
    19000000.0,
    20000000.0,
    21000000.0,
    22000000.0,
    23000000.0,
    24000000.0,
    25000000.0,
    26000000.0,
    27000000.0,
    28000000.0,
    29000000.0,
    0.18602327099739624,
    0.18722734236494554,
    0.18846145605387774,
    0.18973503880879677,
    0.1910116332683303,
    0.19230785670508593,
    0.19359327763062362,
    0.19492178663808446,
    0.19627541562103012,
    0.19767411260748535,
    0.19910912023417518,
    0.20059717004066233,
    0.20214991395167703,
    0.20377574674455423,
    0.20550141242935055,
    0.20732633264521513,
    0.20926309803466,
    0.21132001453758076,
    0.21350024259155148,
    0.2158082944259221,
    0.21823627406715235,
    0.22077982551564485,
    0.2234313284180557,
    0.22617441798799154,
    0.22898787975601548,
    0.2318538374370176,
    0.23474533263175784,
    0.23762854775857783,
    0.24047869967879118,
    0.2432625980187236,
    0.24594785420417423,
    0.24849583995324204,
    0.25088529804076287,
    0.2530790527661364,
    0.2550592547204972,
    0.2568033074799366,
    0.2582908808458577,
    0.25950769607562674,
    0.2604363204229405,
    0.26107838715839343,
    0.2614241172308819,
    0.2614677307766702,
]

# %%
virA_peak_value_transit_obs_beam_corrected = np.zeros_like(virA_peak_value_transit_obs)
cygA_peak_value_beam_corrected = np.zeros_like(cygA_peak_value)
casA_peak_value_beam_corrected = np.zeros_like(casA_peak_value)
cygA_model_peak_value_beam_corrected = np.zeros_like(cygA_model_peak_value)
casA_model_peak_value_beam_corrected = np.zeros_like(casA_model_peak_value)
for freq_ind, freq in enumerate(frequencies):
    use_beam_freq_ind = np.where(np.abs(beam_freqs_mhz-freq) == np.min(np.abs(beam_freqs_mhz-freq)))[0][0]
    virA_peak_value_transit_obs_beam_corrected[freq_ind] = virA_peak_value_transit_obs[freq_ind]/virA_transit_beam_amp[use_beam_freq_ind]
    cygA_peak_value_beam_corrected[freq_ind] = cygA_peak_value[freq_ind]/cygA_beam_amp[use_beam_freq_ind]
    casA_peak_value_beam_corrected[freq_ind] = casA_peak_value[freq_ind]/casA_beam_amp[use_beam_freq_ind]
    casA_model_peak_value_beam_corrected[freq_ind] = casA_model_peak_value[freq_ind]/casA_beam_amp[use_beam_freq_ind]
    cygA_model_peak_value_beam_corrected[freq_ind] = cygA_model_peak_value[freq_ind]/cygA_beam_amp[use_beam_freq_ind]

# %%
plt.plot(frequencies, virA_peak_value_transit_obs, "-o", label="Vir A reconstructed flux, apparent", markersize=3, linewidth=1)
plt.plot(frequencies, virA_peak_value_transit_obs_beam_corrected, "-o", label="Vir A reconstructed flux, beam corrected", markersize=3, linewidth=1)
plt.plot(frequencies, virA_cal_flux, "-o", label="Vir A model flux", markersize=3, linewidth=1)
plt.plot(frequencies, casA_cal_flux, "-o", label="Cas A model flux", markersize=3, linewidth=1)
plt.legend(loc="upper right")
plt.yscale("log")
plt.xlabel("Frequency (MHz)")
plt.ylabel("Flux Density (Jy)")
plt.ylim([7e2, 2e5])
plt.show()

# %%
#plt.plot(frequencies, virA_peak_value_transit_obs, "-o", label="Vir A reconstructed flux, apparent", markersize=3, linewidth=1)
plt.plot(frequencies, virA_peak_value_transit_obs_beam_corrected, "-o", label="Vir A reconstructed flux, beam corrected", markersize=3, linewidth=1)
plt.plot(frequencies, virA_cal_flux, "-o", label="Vir A model flux", markersize=3, linewidth=1)
plt.plot(frequencies, casA_cal_flux, "-o", label="Cas A model flux", markersize=3, linewidth=1)
plt.plot(frequencies, np.exp(np.log(1226) - 0.79 * np.log(np.array(frequencies)/150)))
plt.legend(loc="upper right")
plt.yscale("log")
plt.xlabel("Frequency (MHz)")
plt.ylabel("Flux Density (Jy)")
plt.ylim([7e2, 2e5])
plt.show()

# %%
#plt.plot(frequencies, virA_peak_value_transit_obs, "-o", label="Vir A reconstructed flux, apparent", markersize=3, linewidth=1)
plt.plot(frequencies, virA_peak_value_transit_obs_beam_corrected, "-o", label="Vir A reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:blue")
plt.plot(frequencies, casA_peak_value_beam_corrected, "-o", label="Cas A reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:orange")
plt.plot(frequencies, cygA_peak_value_beam_corrected, "-o", label="Cyg A reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:green")

plt.plot(frequencies, virA_cal_flux, "-x", label="Vir A model flux", markersize=3, linewidth=1, color="tab:blue")
plt.plot(frequencies, casA_cal_flux, "-x", label="Cas A model flux", markersize=3, linewidth=1, color="tab:orange")
plt.plot(frequencies, cygA_cal_flux, "-x", label="Cyg A model flux", markersize=3, linewidth=1, color="tab:green")
#plt.plot(frequencies, casA_peak_value, "-o", label="Cas A reconstructed flux, apparent", markersize=3, linewidth=1)
#plt.plot(frequencies, cygA_peak_value, "-o", label="Cyg A reconstructed flux, apparent", markersize=3, linewidth=1)
#plt.plot(frequencies, np.exp(np.log(1226) - 0.79 * np.log(np.array(frequencies)/150)))
plt.legend(loc="upper right")
plt.yscale("log")
plt.xlabel("Frequency (MHz)")
plt.ylabel("Flux Density (Jy)")
plt.ylim([7e2, 3e5])
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=300)
plt.plot(frequencies, virA_peak_value_transit_obs_beam_corrected, "-o", label="Vir A reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:blue")
plt.plot(frequencies, casA_peak_value_beam_corrected, "-o", label="Cas A reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:orange")
plt.plot(frequencies, cygA_peak_value_beam_corrected, "-o", label="Cyg A reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:green")

plt.plot(frequencies, casA_model_peak_value_beam_corrected, "--D", label="Cas A model reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:orange")
plt.plot(frequencies, cygA_model_peak_value_beam_corrected, "--D", label="Cyg A model reconstructed flux, beam corrected", markersize=3, linewidth=1, color="tab:green")

plt.plot(frequencies, virA_cal_flux, "--x", label="Vir A model flux", markersize=3, linewidth=1, color="tab:blue")
plt.plot(frequencies, casA_cal_flux, "--x", label="Cas A model flux", markersize=3, linewidth=1, color="tab:orange")
plt.plot(frequencies, cygA_cal_flux, "--x", label="Cyg A model flux", markersize=3, linewidth=1, color="tab:green")

#plt.legend(bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.legend(loc="upper right")
plt.yscale("log")
plt.xlabel("Frequency (MHz)")
plt.ylabel("Flux Density (Jy)")
plt.ylim([7e2, 3e5])
plt.tight_layout()
plt.show()
