# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
frequencies = [
    18,
    23,
    27,
    36,
    41,
    46,
    50,
    55,
    59,
    64,
    73,
    78,
    82,
]

# %%
#virA_peak_value = [
#    1807.43,
#    1851.61,
#    1471.28,
#    964.26,
#    793.867,
#    698.225,
#    644.224,
#    543.298,
#    509.026,
#    416.525,
#    331.193,
#    292.24,
#    197.889,
#]  # Imaged using full array
virA_peak_value = [
    2743.85,
    2967.31,
    2649.12,
    1793.02,
    1533.7,
    1334.73,
    1178.48,
    1054.4,
    942.255,
    846.279,
    653.156,
    579.914,
    404.981,
]  # Core only imaging
virA_peak_value_corrected = np.array(virA_peak_value)*2

# %%
tauA_cal_flux = [
    3492.860287,
    3129.290626,
    2855.431542,
    2490.712568,
    2365.12748,
    2259.80257,
    2165.716308,
    2077.183589,
    1991.855738,
    1910.720505,
    1781.661034,
    1752.394433,
    1764.635728,
]
virA_cal_flux = [
    3451.279533,
    3464.56795,
    3369.464194,
    3010.675611,
    2807.40382,
    2616.565933,
    2450.483784,
    2314.325336,
    2206.104675,
    2116.682017,
    1921.902199,
    1762.4961,
    1513.790127,
]
casA_cal_flux = [
    64475.25454,
    53945.26893,
    45777.91111,
    34640.98368,
    30882.81112,
    27910.06043,
    25484.87478,
    23431.97515,
    21638.6604,
    20054.80723,
    17627.88166,
    16997.45192,
    17001.76906,
]

# %%
beam_freqs_hz = [
    10000000.0,
    11000000.0,
    12000000.0,
    13000000.0,
    14000000.0,
    15000000.0,
    16000000.0,
    17000000.0,
    18000000.0,
    19000000.0,
    20000000.0,
    21000000.0,
    22000000.0,
    23000000.0,
    24000000.0,
    25000000.0,
    26000000.0,
    27000000.0,
    28000000.0,
    29000000.0,
    30000000.0,
    31000000.0,
    32000000.0,
    33000000.0,
    34000000.0,
    35000000.0,
    36000000.0,
    37000000.0,
    38000000.0,
    39000000.0,
    40000000.0,
    41000000.0,
    42000000.0,
    43000000.0,
    44000000.0,
    45000000.0,
    46000000.0,
    47000000.0,
    48000000.0,
    49000000.0,
    50000000.0,
    51000000.0,
    52000000.0,
    53000000.0,
    54000000.0,
    55000000.0,
    56000000.0,
    57000000.0,
    58000000.0,
    59000000.0,
    60000000.0,
    61000000.0,
    62000000.0,
    63000000.0,
    64000000.0,
    65000000.0,
    66000000.0,
    67000000.0,
    68000000.0,
    69000000.0,
    70000000.0,
    71000000.0,
    72000000.0,
    73000000.0,
    74000000.0,
    75000000.0,
    76000000.0,
    77000000.0,
    78000000.0,
    79000000.0,
    80000000.0,
    81000000.0,
    82000000.0,
    83000000.0,
    84000000.0,
    85000000.0,
    86000000.0,
    87000000.0,
    88000000.0,
    89000000.0,
    90000000.0,
    91000000.0,
    92000000.0,
    93000000.0,
    94000000.0,
    95000000.0,
    96000000.0,
    97000000.0,
    98000000.0,
    99000000.0,
    100000000.0,
]
beam_freqs_mhz = np.array(beam_freqs_hz) / 1e6
virA_beam_amp=[
    0.8601389172804809,
    0.8580842556152285,
    0.855889001510788,
    0.8536749312766494,
    0.8513977348833855,
    0.8491089441014059,
    0.8468100027192091,
    0.8444829931885742,
    0.8421959423717719,
    0.8401262799715414,
    0.8383036896020923,
    0.8368687244140685,
    0.8358133733033611,
    0.8351364023318764,
    0.8348146494745337,
    0.834773662539599,
    0.8349219841497846,
    0.8351883250045681,
    0.8355184762641347,
    0.8358648790183765,
    0.836197322243808,
    0.8366228241781577,
    0.8368808585175792,
    0.837090834331218,
    0.8372494421375136,
    0.8373548318672255,
    0.8374072790212985,
    0.8374096715926598,
    0.8373593080932573,
    0.8372592718252168,
    0.83710706718494,
    0.8369050679844947,
    0.8366532150036197,
    0.836351329353327,
    0.8359989596113744,
    0.8355960997813169,
    0.8351469004732743,
    0.834650981118682,
    0.8341118108547733,
    0.8335303454891644,
    0.8329101766111081,
    0.8322514580319471,
    0.8315586209965389,
    0.8308321317099143,
    0.8300713210869343,
    0.8292746329796437,
    0.8284382190608901,
    0.8275549523515717,
    0.8266180480828559,
    0.825618367749398,
    0.824542374138256,
    0.8233917747074817,
    0.8221645968385387,
    0.8208277889116558,
    0.8193892585891168,
    0.8178197207482867,
    0.816154704366183,
    0.8143819459354628,
    0.8124953236727241,
    0.8105072030035135,
    0.8084086166638456,
    0.8061608437424134,
    0.8037115100428824,
    0.8011276350926595,
    0.7984172970948575,
    0.7955846280852354,
    0.792616279907944,
    0.7895060015996183,
    0.7862424781361449,
    0.7828042563300595,
    0.779174371085514,
    0.775332903637102,
    0.7712622826417974,
    0.766925319465855,
    0.7622999324354826,
    0.757350712776613,
    0.7520389553040988,
    0.7463354233926671,
    0.7401994548129999,
    0.7335861663290298,
    0.7264716169483789,
    0.7188273451892662,
    0.7106225862982828,
    0.7018313763819491,
    0.6924640298548373,
    0.6825071290279113,
    0.6719716650893949,
    0.66087570543633,
    0.6492530927387417,
    0.637152519032124,
    0.6246163472552626,
]

# %%
virA_peak_value_beam_corrected = np.zeros_like(virA_peak_value_corrected)
for freq_ind, freq in enumerate(frequencies):
    beam_val = virA_beam_amp[np.where(np.abs(beam_freqs_mhz-freq) == np.min(np.abs(beam_freqs_mhz-freq)))[0][0]]
    virA_peak_value_beam_corrected[freq_ind] = virA_peak_value_corrected[freq_ind]/beam_val

# %%
plt.plot(frequencies, virA_peak_value_corrected, "-o", label="Vir A reconstructed flux, apparent", markersize=3, linewidth=1)
plt.plot(frequencies, virA_peak_value_beam_corrected, "-o", label="Vir A reconstructed flux, beam corrected", markersize=3, linewidth=1)
plt.plot(frequencies, virA_cal_flux, "-o", label="Vir A model flux", markersize=3, linewidth=1)
plt.plot(frequencies, casA_cal_flux, "-o", label="Cas A model flux", markersize=3, linewidth=1)
plt.legend(loc="upper right")
plt.yscale("log")
plt.xlabel("Frequency (MHz)")
plt.ylabel("Flux Density (Jy)")
plt.ylim([7e2, 2e5])
plt.show()

# %%
plt.plot(frequencies, virA_peak_value_corrected, "-o", label="Vir A reconstructed flux, apparent", markersize=3, linewidth=1)
plt.plot(frequencies, virA_peak_value_beam_corrected, "-o", label="Vir A reconstructed flux, beam corrected", markersize=3, linewidth=1)
plt.plot(frequencies, virA_cal_flux, "-o", label="Vir A model flux", markersize=3, linewidth=1)
plt.plot(frequencies, casA_cal_flux, "-o", label="Cas A model flux", markersize=3, linewidth=1)
plt.plot(frequencies, np.exp(np.log(1226) - 0.79 * np.log(np.array(frequencies)/150)))
plt.legend(loc="upper right")
plt.yscale("log")
plt.xlabel("Frequency (MHz)")
plt.ylabel("Flux Density (Jy)")
plt.ylim([7e2, 2e5])
plt.show()
