# %%
import sys
sys.path.append("/Users/ruby/Astro/rlb_LWA/LWA_data_preprocessing")
import LWA_preprocessing
import numpy as np
import pyuvdata
import importlib
importlib.reload(LWA_preprocessing)
# Out:
# <module 'LWA_preprocessing' from '/Users/ruby/Astro/rlb_LWA/LWA_data_preprocessing/LWA_preprocessing.py'>

# %%
uvd = pyuvdata.UVData()
uvd.read_uvfits("/Users/ruby/Astro/LWA_data/LWA_data_20220307/20220307_175923_61MHz_calib.uvfits")

# %%
np.shape(uvd.flag_array)
# Out:
# (62128, 1, 192, 4)

# %%
uvd.flag_array[:, :, :, :] = False  # Unflag all

# %%
LWA_preprocessing.flag_outriggers(uvd, inplace=True)

# %%
LWA_preprocessing.plot_autocorrelations(
    uvd,
    plot_save_dir="/Users/ruby/Astro/LWA_data/LWA_data_20220307/debugging_plots",
    plot_file_prefix="",
    time_average=True,
    plot_legend=False,
    plot_flagged_data=False,
    yrange=[0, 100],
)
# Out:
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# ...

# %%
LWA_preprocessing.flag_inactive_antennas(
    uvd, autocorr_thresh=5.0, inplace=True, flag_only=True
)
# Out:
# 122/352 antennas removed due to low autocorrelation power.
# Mean of empty slice
# All-NaN slice encountered

# %%
LWA_preprocessing.plot_autocorrelations(
    uvd,
    plot_save_dir="/Users/ruby/Astro/LWA_data/LWA_data_20220307/debugging_plots",
    plot_file_prefix="flagged",
    time_average=True,
    plot_legend=False,
    plot_flagged_data=False,
    yrange=[0, 100],
)
# Out:
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# ...
