# %%
import pyuvdata
import numpy as np
import os
import sys
import datetime
import importlib
importlib.reload(pyuvdata)
# Out:
# <module 'pyuvdata' from '/opt/devel/rbyrne/envs/py311/lib/python3.11/site-packages/pyuvdata/__init__.py'>

# %%
use_freqs = [
    "41",
    "46",
    "50",
    "55",
    "59",
    "64",
    "69",
    "73",
    "78",
    "82",
]
freq_intervals = [
    [41319824.21875, 48354003.90625],
    [48377929.6875, 56823730.46875],
    [56847656.25, 67398925.78125],
    [67422851.5625, 77615234.375  ],
    [77639160.15625, 82256835.9375 ],
    [82280761.71875, 84649414.0625 ],
]


def concatenate(filenames):

    # Check if all paths exist
    for file_ind, filename in enumerate(filenames):
        for freq_ind, freq in enumerate(use_freqs):
            year = filename[:4]
            month = filename[4:6]
            day = filename[6:8]
            hour = filename[9:11]
            minute = filename[11:13]
            second = filename[13:15]
            path = f"/lustre/pipeline/cosmology/{freq}MHz/{year}-{month}-{day}/{hour}/{year}{month}{day}_{hour}{minute}{second}_{freq}MHz.ms"
            if not os.path.isdir(path):
                print(f"Error: Path {path} not found.")
                return None

    for file_ind, filename in enumerate(filenames):
        for freq_ind, freq in enumerate(use_freqs):
            year = filename[:4]
            month = filename[4:6]
            day = filename[6:8]
            hour = filename[9:11]
            minute = filename[11:13]
            second = filename[13:15]
            path = f"/lustre/pipeline/cosmology/{freq}MHz/{year}-{month}-{day}/{hour}/{year}{month}{day}_{hour}{minute}{second}_{freq}MHz.ms"

            uv_new = pyuvdata.UVData()
            uv_new.read(path)
            uv_new.select(polarizations=[-5, -6])
            uv_new.scan_number_array = None
            if freq_ind == 0:
                uv_freq_new = uv_new
            else:
                uv_freq_new.fast_concat(uv_new, "freq", inplace=True)
        if file_ind == 0:
            uv = uv_freq_new
        else:
            uv.fast_concat(uv_freq_new, "blt", inplace=True, run_check=False)

    chunk_in_frequency(uv, filenames)


def chunk_in_frequency(uv, filenames):
    for interval in np.array(freq_intervals):
        keep_freqs = np.where(
            (uv.freq_array >= interval[0]) & (uv.freq_array <= interval[1])
        )[0]
        uv_freq_band = uv.select(frequencies=uv.freq_array[keep_freqs], inplace=False)

        mean_freq = int(np.mean(uv.freq_array[keep_freqs] / 1e6))
        year = filenames[0][:4]
        month = filenames[0][4:6]
        day = filenames[0][6:8]
        hour = filenames[0][9:11]
        start_minute = filenames[0][11:13]
        start_second = filenames[0][13:15]
        end_minute = filenames[-1][11:13]
        end_second = filenames[-1][13:15]

        outdir = f"/lustre/pipeline/cosmology/concatenated_data/{mean_freq}MHz/{year}-{month}-{day}/{hour}"
        out_filename = f"{year}{month}{day}_{hour}{start_minute}{start_second}-{hour}{end_minute}{end_second}_{mean_freq}MHz.ms"
        if not os.path.isdir(outdir):
            os.system(f"sudo mkdir -p {outdir}")
        uv.write_ms(f"{outdir}/{out_filename}")

        sys.exit()


# dates = np.sort(os.listdir(f"/lustre/pipeline/cosmology/{use_freqs[0]}MHz"))
dates = ["2026-01-06", "2026-01-07", "2026-01-08", "2026-01-09"]
for date in dates:
    hours = np.sort(os.listdir(f"/lustre/pipeline/cosmology/{use_freqs[0]}MHz/{date}"))
    for hour in hours:
        filenames = np.sort(
            os.listdir(f"/lustre/pipeline/cosmology/{use_freqs[0]}MHz/{date}/{hour}")
        )
        use_timestamps = []
        use_filenames = []
        for filename in filenames:
            new_time = datetime.datetime(
                int(filename[:4]),  # year
                int(filename[4:6]),  # month
                int(filename[6:8]),  # day
                int(filename[9:11]),  # hour
                int(filename[11:13]),  # minute
                int(filename[13:15]),  # second
            )
            if len(use_timestamps) == 0:
                use_timestamps.append(new_time)
                use_filenames.append(filename)
            else:
                if np.abs(new_time - np.min(use_timestamps)) < datetime.timedelta(minutes=2):
                    use_timestamps.append(new_time)
                    use_filenames.append(filename)
            if len(use_timestamps) == 12:
                concatenate(use_filenames)
                use_timestamps = []
                use_filenames = []
# Out:
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402136058438316 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402136058438316 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402136058438316 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.40206042312326 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.40206042312326 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.40206042312326 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.4021245426286555 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.4021245426286555 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.4021245426286555 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402118751200362 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402118751200362 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402118751200362 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402118587754387 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402118587754387 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402118587754387 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402105947379823 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402105947379823 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402105947379823 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402116286224981 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402116286224981 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402116286224981 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122033376656 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122033376656 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122033376656 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402115287150934 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402115287150934 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402115287150934 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397496025523793 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397496025523793 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397496025523793 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397420390168918 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397420390168918 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397420390168918 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397484509674257 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397484509674257 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397484509674257 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397478718245935 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397478718245935 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397478718245935 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397478554839836 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397478554839836 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397478554839836 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.39746591446584 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.39746591446584 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.39746591446584 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397476253271179 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397476253271179 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397476253271179 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.39748200046327 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.39748200046327 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.39748200046327 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397475254237008 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397475254237008 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397475254237008 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.397482470781171 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The provided name zenith is already used but has different parameters. Adding another entry with the same name but a different ID and parameters.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392858893627988 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392858893627988 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392858893627988 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392783258353518 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392783258353518 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392783258353518 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392847377777855 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392847377777855 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392847377777855 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392841586390034 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392841586390034 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392841586390034 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392841422944059 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392841422944059 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392841422944059 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.3928287825688415 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.3928287825688415 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.3928287825688415 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392839121415278 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392839121415278 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392839121415278 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392844868567465 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392844868567465 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392844868567465 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392838122340606 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392838122340606 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392838122340606 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.392845338885365 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The provided name zenith is already used but has different parameters. Adding another entry with the same name but a different ID and parameters.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388217227246798 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388217227246798 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388217227246798 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388141591972271 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388141591972271 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388141591972271 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388205711477667 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388205711477667 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388205711477667 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388199920008219 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388199920008219 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388199920008219 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388199756562699 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388199756562699 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388199756562699 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388187116188192 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388187116188192 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388187116188192 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.38819745503406 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.38819745503406 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.38819745503406 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203672584609 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203202226748 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.388203202226748 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# ...
# The provided name zenith is already used but has different parameters. Adding another entry with the same name but a different ID and parameters.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351065994646177 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351065994646177 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351065994646177 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.350990359412606 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.350990359412606 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.350990359412606 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351054478877529 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351054478877529 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351054478877529 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351048687408138 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351048687408138 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351048687408138 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351048524043648 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351048524043648 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351048524043648 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.35103588362864 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.35103588362864 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.35103588362864 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351046222474508 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351046222474508 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351046222474508 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351051969666628 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351051969666628 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351051969666628 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351045223358739 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351045223358739 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351045223358739 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.351052439984528 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The provided name zenith is already used but has different parameters. Adding another entry with the same name but a different ID and parameters.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 118
#     116         use_filenames.append(filename)
#     117 if len(use_timestamps) == 12:
# --> 118     concatenate(use_filenames)
#     119     use_timestamps = []
#     120     use_filenames = []
#
# Cell In[5], line 62, in concatenate(filenames)
#      59     else:
#      60         uv.fast_concat(uv_freq_new, "blt", inplace=True, run_check=False)
# ---> 62 chunk_in_frequency(uv, filenames)
#
# Cell In[5], line 86, in chunk_in_frequency(uv, filenames)
#      84 if not os.path.isdir(outdir):
#      85     os.system(f"sudo mkdir -p {outdir}")
# ---> 86 uv.write_ms(f"{outdir}/{out_filename}")
#      88 sys.exit()
#
# File /opt/devel/rbyrne/envs/py311/lib/python3.11/site-packages/pyuvdata/uvdata/uvdata.py:11410, in UVData.write_ms(self, filename, force_phase, model_data, corrected_data, flip_conj, clobber, run_check, check_extra, run_check_acceptability, strict_uvw_antpos_check, check_autos, fix_autos)
#   11405     raise ValueError(
#   11406         "Cannot write out metadata only objects to a measurement set file."
#   11407     )
#   11409 ms_obj = self._convert_to_filetype("ms")
# > 11410 ms_obj.write_ms(
#   11411     filename,
#   11412     force_phase=force_phase,
#   11413     model_data=model_data,
#   11414     corrected_data=corrected_data,
#   11415     flip_conj=flip_conj,
#   11416     clobber=clobber,
#   11417     run_check=run_check,
#   11418     check_extra=check_extra,
#   11419     run_check_acceptability=run_check_acceptability,
#   11420     strict_uvw_antpos_check=strict_uvw_antpos_check,
#   11421     check_autos=check_autos,
#   11422     fix_autos=fix_autos,
#   11423 )
#   11424 del ms_obj
#
# File /opt/devel/rbyrne/envs/py311/lib/python3.11/site-packages/pyuvdata/uvdata/ms.py:89, in MS.write_ms(self, filepath, force_phase, model_data, corrected_data, flip_conj, clobber, run_check, check_extra, run_check_acceptability, strict_uvw_antpos_check, check_autos, fix_autos)
#      87         print("File exists; clobbering")
#      88     else:
# ---> 89         raise OSError("File exists; skipping")
#      91 # Determine polarization order for writing out in CASA standard order, check
#      92 # if this order can be represented by a single slice.
#      93 pol_order = utils.pol.determine_pol_order(self.polarization_array, order="CASA")
#
# OSError: File exists; skipping

# %%
uv = pyuvdata.UVData()
uv.read("/lustre/pipeline/slow/41MHz/2026-01-11/00/20260111_001710_41MHz.ms")
uv.freq_array[np.where(np.abs(uv.freq_array - 41.29589844 * 1e6) < 1)[0][0]]
# Out:
# Setting telescope_location to value in known_telescopes for OVRO-LWA.
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 5.318701283600404 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# np.float64(41295898.4375)

# %%
freq_interval_start_values_mhz = np.array([28.328125, 41.29589844, 48.35400391, 56.82373047, 67.39892578, 77.61523438, 82.25683594, 84.64941406])
# freq_interval_start_values_mhz = freq_interval_start_values_mhz[1:]  # Strip first value
freq_intervals = []
for interval_ind in range(len(freq_interval_start_values_mhz)-1):
    start_value = uv.freq_array[
        np.where(
            np.abs(
                uv.freq_array
                - (
                    freq_interval_start_values_mhz[interval_ind] * 1e6
                    + np.mean(uv.channel_width)
                )
            )
            < 1
        )[0][0]
    ]
    end_value = uv.freq_array[
        np.where(
            np.abs(
                uv.freq_array - freq_interval_start_values_mhz[interval_ind + 1] * 1e6
            )
            < 1
        )[0][0]
    ]
    freq_intervals.append([start_value, end_value])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 freq_intervals = []
#       4 for interval_ind in range(len(freq_interval_start_values_mhz)-1):
# ----> 5     start_value = uv.freq_array[
#       6         np.where(
#       7             np.abs(
#       8                 uv.freq_array
#       9                 - (
#      10                     freq_interval_start_values_mhz[interval_ind] * 1e6
#      11                     + np.mean(uv.channel_width)
#      12                 )
#      13             )
#      14             < 1
#      15         )[0][0]
#      16     ]
#      17     end_value = uv.freq_array[
#      18         np.where(
#      19             np.abs(
#    (...)
#      23         )[0][0]
#      24     ]
#      25     freq_intervals.append([start_value, end_value])
#
# NameError: name 'uv' is not defined

# %%
print(np.array(freq_intervals))
# Out:
# [[41319824.21875 48354003.90625]
#  [48377929.6875  56823730.46875]
#  [56847656.25    67398925.78125]
#  [67422851.5625  77615234.375  ]
#  [77639160.15625 82256835.9375 ]
#  [82280761.71875 84649414.0625 ]]

# %%
for interval in np.array(freq_intervals):
    keep_freqs = np.where((uv.freq_array >= interval[0]) & (uv.freq_array <= interval[1]))[0]
    uv_freq_band = uv.select(frequencies = uv.freq_array[keep_freqs], inplace=False)
    mean_freq = int(np.mean(uv.freq_array[keep_freqs]/1e6))
    print(mean_freq)
# Out:
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# 44
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# 52
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# 62
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# 72
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
# 79
# 83
# The uvw_array does not match the expected values given the antenna positions. The largest discrepancy is 7.402122503694557 meters. This is a fairly common situation but might indicate an error in the antenna positions, the uvws or the phasing.
